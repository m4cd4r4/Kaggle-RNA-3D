# %% [markdown]
# # Stanford RNA 3D Folding Part 2 - Data Exploration
#
# This notebook explores the competition dataset and provides initial insights.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

# Set style
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (12, 6)

# Paths
DATA_DIR = Path('../data/raw')
PROCESSED_DIR = Path('../data/processed')

# %% [markdown]
# ## 1. Load Data
#
# Load the training and test datasets.

# %%
# List all files in data directory
data_files = list(DATA_DIR.glob('*'))
print(f"Found {len(data_files)} files:")
for f in data_files:
    print(f"  - {f.name} ({f.stat().st_size / 1024 / 1024:.2f} MB)")

# %% [markdown]
# ## 2. Dataset Overview
#
# Understand the structure of the data.

# %%
# TODO: Load main dataset once extracted
# df_train = pd.read_csv(DATA_DIR / 'train.csv')
# df_test = pd.read_csv(DATA_DIR / 'test.csv')
# 
# print("Training set shape:", df_train.shape)
# print("Test set shape:", df_test.shape)
# 
# df_train.head()

# %% [markdown]
# ## 3. RNA Sequence Analysis
#
# Analyze the RNA sequences.

# %%
# Sequence length distribution
# sequence_lengths = df_train['sequence'].str.len()
# 
# plt.figure(figsize=(12, 5))
# plt.subplot(1, 2, 1)
# plt.hist(sequence_lengths, bins=50, edgecolor='black')
# plt.xlabel('Sequence Length')
# plt.ylabel('Count')
# plt.title('Distribution of RNA Sequence Lengths')
# 
# plt.subplot(1, 2, 2)
# plt.boxplot(sequence_lengths)
# plt.ylabel('Sequence Length')
# plt.title('Sequence Length Boxplot')
# plt.tight_layout()
# plt.show()
# 
# print(f"Min length: {sequence_lengths.min()}")
# print(f"Max length: {sequence_lengths.max()}")
# print(f"Mean length: {sequence_lengths.mean():.2f}")
# print(f"Median length: {sequence_lengths.median():.2f}")

# %% [markdown]
# ## 4. Nucleotide Composition
#
# Analyze the distribution of nucleotides (A, U, G, C).

# %%
# def get_nucleotide_composition(sequence):
#     total = len(sequence)
#     return {
#         'A': sequence.count('A') / total,
#         'U': sequence.count('U') / total,
#         'G': sequence.count('G') / total,
#         'C': sequence.count('C') / total
#     }
# 
# # Calculate composition for all sequences
# compositions = df_train['sequence'].apply(get_nucleotide_composition)
# composition_df = pd.DataFrame(compositions.tolist())
# 
# # Plot
# composition_df.mean().plot(kind='bar', color=['#FF6B6B', '#4ECDC4', '#45B7D1', '#FFA07A'])
# plt.xlabel('Nucleotide')
# plt.ylabel('Average Proportion')
# plt.title('Average Nucleotide Composition in RNA Sequences')
# plt.xticks(rotation=0)
# plt.ylim(0, 0.4)
# plt.tight_layout()
# plt.show()

# %% [markdown]
# ## 5. Target Distribution
#
# Analyze the 3D structure targets.

# %%
# TODO: Analyze target structure once data format is understood

# %% [markdown]
# ## 6. Missing Data Analysis
#
# Check for missing values.

# %%
# missing = df_train.isnull().sum()
# if missing.sum() > 0:
#     print("Missing values:")
#     print(missing[missing > 0])
# else:
#     print("No missing values found!")

# %% [markdown]
# ## 7. Save Processed Data
#
# Save any preprocessed features.

# %%
# PROCESSED_DIR.mkdir(exist_ok=True)
# # Save processed data
# # df_processed.to_csv(PROCESSED_DIR / 'train_processed.csv', index=False)
